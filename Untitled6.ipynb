# %%
# sample_with_errors.py

def sample_function():
print("Hello, World!")

x=5
if x>3:
 print("x is greater than 3")
# Out:
#   File "<ipython-input-3-21b61b7a10f6>", line 4
#     print("Hello, World!")
#     ^
# IndentationError: expected an indented block after function definition on line 3
